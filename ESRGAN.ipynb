# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ESRGAN
# Out:
# /content/drive/MyDrive/ESRGAN

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/ESRGAN'

# %%
# !git clone https://github.com/xinntao/ESRGAN.git
# Out:
# Cloning into 'ESRGAN'...
# remote: Enumerating objects: 225, done.
# remote: Total 225 (delta 0), reused 0 (delta 0), pack-reused 225
# Receiving objects: 100% (225/225), 24.86 MiB | 14.24 MiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
# %cd ESRGAN
# Out:
# /content/drive/MyDrive/ESRGAN/ESRGAN

# %%
# !python test.py
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...
# 1 comic
# 2 cropped

# %% [markdown]
# Meta Image

# %%
from google.colab import drive
from PIL import Image
import matplotlib.pyplot as plt

# Path to your image
image_path = '/content/drive/MyDrive/ESRGAN/ESRGAN/LR/comic.png'

# %%
# Open the image
image = Image.open(image_path)

# Plot the image
plt.imshow(image)
plt.axis('off') # Hide axis
plt.show()

# %% [markdown]
# Augmented Result

# %%
image_path = '/content/drive/MyDrive/ESRGAN/ESRGAN/results/comic_rlt.png'

# %%
# Open the image
image = Image.open(image_path)

# Plot the image
plt.imshow(image)
plt.axis('off') # Hide axis
plt.show()
